# %%
import seaborn
from scipy.optimize import curve_fit
# %matplotlib inline

# %%
def func(x, a, b):
    return a + b * x

# %%
df = seaborn.load_dataset('anscombe')

# %%
df.dataset.unique()
# Out:
# array(['I', 'II', 'III', 'IV'], dtype=object)

# %%
series = df.dataset.unique()

# %%
for s in series:
    tmp = df.loc[df.dataset == s]
    print('Data {0}'.format(s))
    print('Mean x: {0:.1f}'.format(tmp.x.mean()))
    print('Mean y: {0:.1f}'.format(tmp.y.mean()))
    print('Variance x: {0:.2f}'.format(tmp.x.var()))
    print('Variance y: {0:.2f}'.format(tmp.y.var()))
    print('Correlation between x and y: {0:.3f}'.format(tmp.x.corr(tmp.y)))
    popt, pcov = curve_fit(func, tmp.x, tmp.y)
    print('Linear regression coefficients: y = {a:.2f} + {b:.2f}x'.format(a=popt[0], b=popt[1]))
    print('\n')
# Out:
# Data I
# Mean x: 9.0
# Mean y: 7.5
# Variance x: 11.00
# Variance y: 4.13
# Correlation between x and y: 0.816
# Linear regression coefficients: y = 3.00 + 0.50x
#
#
# Data II
# Mean x: 9.0
# Mean y: 7.5
# Variance x: 11.00
# Variance y: 4.13
# Correlation between x and y: 0.816
# Linear regression coefficients: y = 3.00 + 0.50x
#
#
# Data III
# Mean x: 9.0
# Mean y: 7.5
# Variance x: 11.00
# Variance y: 4.12
# Correlation between x and y: 0.816
# Linear regression coefficients: y = 3.00 + 0.50x
#
#
# Data IV
# Mean x: 9.0
# Mean y: 7.5
# Variance x: 11.00
# Variance y: 4.12
# Correlation between x and y: 0.817
# Linear regression coefficients: y = 3.00 + 0.50x

# %%
import seaborn as sns
# Setting up params for graphic
sns.set(style="white")
sns.set_context("talk")
sns.despine(left=True)

# Plotting
catcher = sns.lmplot("x", "y", col="dataset", hue="dataset", data=df,
           col_wrap=2, ci=None, palette="husl", size=4,
           scatter_kws={"s": 50, "alpha": 0.7}, aspect=1).fig.show()

sns.despine()
# Out:
# /Users/karve/anaconda3/envs/dev/lib/python3.6/site-packages/matplotlib/figure.py:459: UserWarning: matplotlib is currently using a non-GUI backend, so cannot show the figure
#   "matplotlib is currently using a non-GUI backend, "
