# %% [markdown]
# # Before you run this notebook
# 1. `pip install quilt` (if you don't have `quilt` installed)
# 1. `quilt install akarve/examples`

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import quilt

# %%
quilt.install("examples/world100m", force=True)
from quilt.data.examples import world100m
# Out:
# Downloading package metadata...
# All fragments are already downloaded!

# %%
df = world100m.men()
df
# Out:
#               Athlete       Country  Time (seconds)            Date  Notes
# 0          Usain Bolt       Jamaica            9.58    Aug 16, 2009    nan
# 1          Usain Bolt       Jamaica            9.69    Aug 16, 2008    nan
# 2          Usain Bolt       Jamaica            9.72    May 31, 2008    nan
# 3        Asafa Powell       Jamaica            9.74    Sept 9, 2007    nan
# 4        Asafa Powell       Jamaica            9.77   June 14, 2005    nan
# 5      Tim Montgomery           USA            9.78  Sept. 14, 2002  doped
# 6      Maurice Greene           USA            9.79   June 16, 1999    nan
# 7      Donovan Bailey        Canada            9.84   July 27, 1996    nan
# 8       Leroy Burrell           USA            9.85    July 6, 1994    nan
# 9          Carl Lewis           USA            9.86   Aug. 25, 1991    nan
# 10      Leroy Burrell           USA            9.90   June 14, 1991    nan
# 11         Carl Lewis           USA            9.92  Sept. 24, 1988    nan
# 12       Calvin Smith           USA            9.93    July 3, 1983    nan
# 13          Jim Hines           USA            9.95   Oct. 14, 1968    nan
# 14          Jim Hines           USA            9.99   June 20, 1968    nan
# 15         Armin Hary  West Germany           10.00   June 21, 1960    nan
# 16    Willie Williams           USA           10.10    Aug. 3, 1956    nan
# 17        Jesse Owens           USA           10.20   June 20, 1936    nan
# 18     Percy Williams        Canada           10.30    Aug. 9, 1930    nan
# 19    Charles Paddock           USA           10.40  April 23, 1921    nan
# 20  Donald Lippincott           USA           10.60    July 6, 1912    nan

# %%
# %matplotlib inline
x = df['Time (seconds)']
y = df['Date']
plt.figure(figsize=[12, 6])



plt.subplot(122)
plt.title("Men's 100 meter world records")
plt.plot(y, x, 'crimson')

plt.subplot(121)
axes = plt.gca()
axes.set_ylim([0, 11])
plt.title("Men's 100 meter world records")
plt.plot(y, x, 'crimson')
